# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px">
#
# Виктория привет! 👋 Поздравляю с первым выполненным проектом.
#
# Меня зовут Рустам Муртазин, и я буду делать ревью проектной работы по предобработке данных. Давай будем общаться на **«ты»**. Если это неприемлемо, обязательно напиши мне в комментариях — мы перейдем на **«вы»**.
#
# Ты проделала большую работу над проектом, однако в любом деле всегда можно можно что-то улучшить. Моя основная цель — не показать, что где-то совершены какие-либо ошибки, а поделиться своим опытом, который поможет тебе в дальнейших работах. Далее в файле ты сможешь увидеть мои комментарии, постарайся учесть их при выполнении следующих заданий.
#
# Обрати внимание в первую очередь на те, что помечаны <span style="color:red">красным цветом</span>. После их доработки проект будет принят. <span style="color:green">Зеленым цветом</span> отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах. <span style="color:orange">Оранжевым цветом</span> выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).
#
# Давай работать над проектом в диалоге: если ты **что-то меняешь** в проекте по моим рекомендациям — **пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее».
#
# В целом работа хорошая, видно, что ты старалась. Дорабатывай комментарии и отправляй работу на повторное ревью, я буду ждать 😉
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 </h2>
#
# Спасибо, за быструю и качественную доработку комментариев! Все моменты были исправлены, так что работу я принимаю. Ты большая молодец, что исправила все комментарии (и оранжевые тоже). Приятно быть полезным)
#
# В общем получилась классная работа. Благодарю за старания и интерес и желаю успехов в дальнейших проектах 😊
#
# </div>

# %% [markdown]
# ## Исследование надёжности заёмщиков
#
# Заказчик — кредитный отдел банка. Нужно разобраться, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок. Входные данные от банка — статистика о платёжеспособности клиентов.
#
# Результаты исследования будут учтены при построении модели **кредитного скоринга** — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.
#
# <font color=006699>
# <h4> Доработано после ревью </h4><br>
# Цель работы - ответить на вопросы: <br>
# -Есть ли зависимость между наличием детей и возвратом кредита в срок?<br>
# -Есть ли зависимость между семейным положением и возвратом кредита в срок?<br>
# -Есть ли зависимость между уровнем дохода и возвратом кредита в срок?<br>
# -Как разные цели кредита влияют на его возврат в срок?<br>
#
#
# Работать будем с выгрузкой данных data.csv. <br>Планируем изучить данные визуально, предобработать их заменив пропуски, исключить дублирование, если оно есть. Также планируем лемматизировать данные для дальнейшего анализа и категоризации.<br>
#
# ### Содержание работы:
# 1. [Шаг 1. Изучение данных](#p1)
# 2. [Шаг 2. Предобработка данных](#p2)
#     <br>2.1 [Обработка пропусков](#p2_1)
#     <br>2.2 [Замена типа данных](#p2_2)
#     <br>2.3 [Обработка дубликатов](#p2_3)
#     <br>2.4 [Лемматизация](#p2_4)
#     <br>2.5 [Категоризация данных](#p2_5)
# 3. [Шаг 3. Ответы на вопросы](#p3)
# 4. [Шаг 4. Общий вывод](#p4)
# </font>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 </h2>
#
# Супер, то что надо!
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# Перед началом основного блока исследования полезно описать данные, с которыми работаешь, какие шаги планируешь выполнить, четко сформулировать цель работы. Здесь также можно добавить кликабельное [оглавление](https://fooobar.com/questions/49721/markdown-to-create-pages-and-table-of-contents) 🙃
#
# </div>

# %% [markdown]
# *Буду благодарна за любую критику, предложения по улучшению проекта!*

# %% [markdown]
# ### Шаг 1. Изучение данных <a name="p1"></a>

# %%
import pandas as pd
df = pd.read_csv('/datasets/data.csv')
df.head(10)
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1   -8437.673028         42    высшее             0
# 1         1   -4024.803754         36   среднее             1
# 2         0   -5623.422610         33   Среднее             1
# 3         3   -4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
# 5         0    -926.185831         27    высшее             0
# 6         0   -2879.202052         43    высшее             0
# 7         0    -152.779569         50   СРЕДНЕЕ             1
# 8         2   -6929.865299         35    ВЫСШЕЕ             0
# 9         0   -2188.756445         41   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.639453
# 1   женат / замужем                 0      F   сотрудник     0  112080.014102
# 2   женат / замужем                 0      M   сотрудник     0  145885.952297
# 3   женат / замужем                 0      M   сотрудник     0  267628.550329
# 4  гражданский брак                 1      F   пенсионер     0  158616.077870
# 5  гражданский брак                 1      M   компаньон     0  255763.565419
# 6   женат / замужем                 0      F   компаньон     0  240525.971920
# 7   женат / замужем                 0      M   сотрудник     0  135823.934197
# 8  гражданский брак                 1      F   сотрудник     0   95856.832424
# 9   женат / замужем                 0      M   сотрудник     0  144425.938277
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# 2               покупка жилья
# 3  дополнительное образование
# 4             сыграть свадьбу
# 5               покупка жилья
# 6           операции с жильем
# 7                 образование
# 8       на проведение свадьбы
# 9     покупка жилья для семьи

# %%
df.columns
# Out:
# Index(['children', 'days_employed', 'dob_years', 'education', 'education_id',
#        'family_status', 'family_status_id', 'gender', 'income_type', 'debt',
#        'total_income', 'purpose'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
# children            21525 non-null int64
# days_employed       19351 non-null float64
# dob_years           21525 non-null int64
# education           21525 non-null object
# education_id        21525 non-null int64
# family_status       21525 non-null object
# family_status_id    21525 non-null int64
# gender              21525 non-null object
# income_type         21525 non-null object
# debt                21525 non-null int64
# total_income        19351 non-null float64
# purpose             21525 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# ### Вывод шаг 1

# %% [markdown]
# Названия столбцов вполне корректные.
#
# Обнаружены пустые значения в столбцах `days_employed`, `total_income`. Это количественные переменные.
#
# Одновременно с этим, визуально наблюдаются странности с Количеством отработанных дней: есть отрицательные значения, что в теории невозможно.

# %% [markdown]
# ### Шаг 2. Предобработка данных <a name="p2"></a>

# %% [markdown]
# ### 2.1 Обработка пропусков <a name="p2_1"></a>

# %% [markdown]
# Проанализируем пропуски в столбце **Доход**.

# %%
df[df['total_income'].isna()].head(5)
# Out:
#     children  days_employed  dob_years education  education_id  \
# 12         0            NaN         65   среднее             1
# 26         0            NaN         41   среднее             1
# 29         0            NaN         63   среднее             1
# 41         0            NaN         50   среднее             1
# 55         0            NaN         54   среднее             1
#
#             family_status  family_status_id gender  income_type  debt  \
# 12       гражданский брак                 1      M    пенсионер     0
# 26        женат / замужем                 0      M  госслужащий     0
# 29  Не женат / не замужем                 4      F    пенсионер     0
# 41        женат / замужем                 0      F  госслужащий     0
# 55       гражданский брак                 1      F    пенсионер     1
#
#     total_income                           purpose
# 12           NaN                   сыграть свадьбу
# 26           NaN                       образование
# 29           NaN  строительство жилой недвижимости
# 41           NaN  сделка с подержанным автомобилем
# 55           NaN                   сыграть свадьбу

# %% [markdown]
# Вычислим медианный и средний доход по типу занятости кредитуемых.

# %%
df.groupby('income_type').agg({'total_income':['count','median','mean']})
# Out:
#                 total_income
#                        count         median           mean
# income_type
# безработный                2  131339.751676  131339.751676
# в декрете                  1   53829.130729   53829.130729
# госслужащий             1312  150447.935283  170898.309923
# компаньон               4577  172357.950966  202417.461462
# пенсионер               3443  118514.486412  137127.465690
# предприниматель            1  499163.144947  499163.144947
# сотрудник              10014  142594.396847  161380.260488
# студент                    1   98201.625314   98201.625314

# %% [markdown]
# Поскольку есть категории с малой выборкой, среднее по типу дохода не очень информативно.
#
# Проанилизируем доход по возрастным категориям разбив их на 3 группы возраста:
# 1. до 30 лет (студенты, начало карьеры)
# 2. 30-50 лет (активная трудовая деятельность)
# 3. 50-75 лет (закат карьеры, пенсионеры)

# %%
df['age_groups'] = pd.cut(df['dob_years'],[df['dob_years'].min(),30,50,df['dob_years'].max()],right=False,
                          labels=['0 - 30','30 - 50','50 - 100'])
df.groupby('age_groups').agg({'total_income':['count','median','mean']})
# Out:
#            total_income
#                   count         median           mean
# age_groups
# 0 - 30             2975  142183.724613  159549.040225
# 30 - 50            9943  154513.982083  177678.900933
# 50 - 100           6432  133663.456146  155210.817900

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Супер! Обрати внимание, у данного метода есть параметр `labels`, так можно оформить группы красивее 😊
#
# </div>

# %% [markdown]
# <font color=006699>Добавила лэйблы 😊</font>
#
# Заменим Nan на медианный доход по соответствующей возрастной группе и проверим себя.

# %%
df['total_income'] = df['total_income'].fillna(df.groupby('age_groups')['total_income'].transform('median'))
df[df['total_income'].isna()]
# Out:
# Empty DataFrame
# Columns: [children, days_employed, dob_years, education, education_id, family_status, family_status_id, gender, income_type, debt, total_income, purpose, age_groups]
# Index: []

# %% [markdown]
# Анализируя столбец **общий трудовой стаж в днях**, не совсем понятно, как вообще стаж может быть отрицательным и почему он настолько дробный.

# %%
# преобразуем дни в года
df['working_years'] = df['days_employed'] / 365
df[['days_employed','working_years']].sort_values(by='days_employed', ascending=False).head(5)
# Out:
#        days_employed  working_years
# 6954   401755.400475    1100.699727
# 10006  401715.811749    1100.591265
# 7664   401675.093434    1100.479708
# 2156   401674.466633    1100.477991
# 7794   401663.850046    1100.448904

# %% [markdown]
# Более того, есть вопрос, как человек может проработаь 1100 лет?
# Можно сделать вывод, что данные в столбце days_employed очень странные и не понятно в какую сторону их модернизировать. Может название столбца вводит нас в заблуждение и это не дни, а часы?
#
# Мы бы предложили задать вопрос разработчику, но поспольку в ТЗ от зказчика нет задания просчитать зависимость отработанных дней и возврата кредита, пока просто заменим Nan на пустоту.

# %%
df['days_employed'] = df['days_employed'].fillna('')
df.drop(['age_groups','working_years'], axis='columns', inplace=True) #удаляю ненужные дополнительно созданные столбцы

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
# children            21525 non-null int64
# days_employed       21525 non-null object
# dob_years           21525 non-null int64
# education           21525 non-null object
# education_id        21525 non-null int64
# family_status       21525 non-null object
# family_status_id    21525 non-null int64
# gender              21525 non-null object
# income_type         21525 non-null object
# debt                21525 non-null int64
# total_income        21525 non-null float64
# purpose             21525 non-null object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 2.0+ MB

# %% [markdown]
# ### Вывод 2.1

# %% [markdown]
# Мы обработали пропуски для дальнейшнй работы.
#
# Есть вопросы к данным, но на реализацию итоговой задачи недостатки выборки повлиять не должны.

# %% [markdown]
# ### 2.2 Замена типа данных <a name="p2_2"></a>

# %% [markdown]
# Для удобства восприятия преобразуем Доход в целочисленные значения.
#
# Да, мы теряем копейки, но для нашей задачи они не сильно важны.
#
# Да и пенсионеры тут с медианным доходом в 118 тысяч какие-то зажиточные))
# Может быть банк нероссийский конечно)

# %%
df['total_income'].astype('int')
# Out:
# 0        253875
# 1        112080
# 2        145885
# 3        267628
# 4        158616
#           ...
# 21520    224791
# 21521    155999
# 21522     89672
# 21523    244093
# 21524     82047
# Name: total_income, Length: 21525, dtype: int64

# %% [markdown]
# Так-то лучше.
#
# Проверим данные на дубли.

# %% [markdown]
# ### 2.3 Обработка дубликатов <a name="p2_3"></a>

# %%
df[df.duplicated()].sort_values(by='dob_years', ascending=True)
# Out:
#        children days_employed  dob_years education  education_id  \
# 19321         0                       23   среднее             1
# 18328         0                       29    высшее             0
# 21281         1                       30    высшее             0
# 18349         1                       30    высшее             0
# 13878         1                       31   среднее             1
# 16904         1                       32    высшее             0
# 4182          1                       34    ВЫСШЕЕ             0
# 9238          2                       34   среднее             1
# 13773         0                       35   среднее             1
# 14432         2                       36    высшее             0
# 12375         1                       37   среднее             1
# 19387         0                       38    высшее             0
# 16902         2                       39   среднее             1
# 17774         1                       40   среднее             1
# 10697         0                       40   среднее             1
# 2849          0                       41   среднее             1
# 20165         0                       42   среднее             1
# 17755         1                       43   среднее             1
# 13025         1                       44   среднее             1
# 13942         0                       44   среднее             1
# 19184         0                       46   среднее             1
# 16378         0                       46   среднее             1
# 11791         0                       47   среднее             1
# 21132         0                       47   среднее             1
# 16176         0                       47   среднее             1
# 19832         0                       48   среднее             1
# 14832         0                       50   среднее             1
# 17379         0                       54    высшее             0
# 18563         0                       54   среднее             1
# 21415         0                       54   среднее             1
# 9627          0                       56   среднее             1
# 19041         0                       56   среднее             1
# 18521         0                       56   среднее             1
# 20116         0                       57   среднее             1
# 19946         0                       57   среднее             1
# 7808          0                       57   среднее             1
# 15273         0                       57   среднее             1
# 12373         0                       58   среднее             1
# 5557          0                       58   среднее             1
# 8583          0                       58    высшее             0
# 15091         0                       58   среднее             1
# 18755         0                       58   среднее             1
# 12736         0                       59   среднее             1
# 15188         0                       60   среднее             1
# 21032         0                       60   среднее             1
# 4851          0                       60   среднее             1
# 19688         0                       61   среднее             1
# 10462         0                       62   среднее             1
# 10994         0                       62   среднее             1
# 10864         0                       62   среднее             1
# 18428         0                       64   среднее             1
# 13639         0                       64   среднее             1
# 20702         0                       64   среднее             1
# 9528          0                       66   среднее             1
#
#                family_status  family_status_id gender  income_type  debt  \
# 19321  Не женат / не замужем                 4      F    сотрудник     0
# 18328        женат / замужем                 0      M    сотрудник     0
# 21281        женат / замужем                 0      F    сотрудник     0
# 18349        женат / замужем                 0      F  госслужащий     0
# 13878        женат / замужем                 0      F    компаньон     0
# 16904        женат / замужем                 0      F    сотрудник     0
# 4182        гражданский брак                 1      F    сотрудник     0
# 9238         женат / замужем                 0      F    сотрудник     0
# 13773       гражданский брак                 1      F    сотрудник     0
# 14432        женат / замужем                 0      F  госслужащий     0
# 12375        женат / замужем                 0      F    сотрудник     0
# 19387       гражданский брак                 1      F    компаньон     0
# 16902       гражданский брак                 1      F    сотрудник     0
# 17774       гражданский брак                 1      F    компаньон     0
# 10697       гражданский брак                 1      F    компаньон     0
# 2849         женат / замужем                 0      F    сотрудник     0
# 20165        женат / замужем                 0      F    сотрудник     0
# 17755        женат / замужем                 0      M    сотрудник     0
# 13025        женат / замужем                 0      F    сотрудник     0
# 13942        женат / замужем                 0      F    сотрудник     0
# 19184        женат / замужем                 0      F    сотрудник     0
# 16378        женат / замужем                 0      F    сотрудник     0
# 11791        женат / замужем                 0      F    сотрудник     0
# 21132        женат / замужем                 0      F    сотрудник     0
# 16176        женат / замужем                 0      F    сотрудник     0
# 19832        женат / замужем                 0      F    сотрудник     0
# 14832  Не женат / не замужем                 4      F    сотрудник     0
# 17379        женат / замужем                 0      M    компаньон     0
# 18563        женат / замужем                 0      F    сотрудник     0
# 21415        женат / замужем                 0      F    пенсионер     0
# 9627         женат / замужем                 0      F    пенсионер     0
# 19041       гражданский брак                 1      F    сотрудник     0
# 18521       гражданский брак                 1      F    сотрудник     0
# 20116       гражданский брак                 1      M    пенсионер     0
# 19946        женат / замужем                 0      F    сотрудник     0
# 7808        гражданский брак                 1      F    пенсионер     0
# 15273       гражданский брак                 1      F    пенсионер     0
# 12373        женат / замужем                 0      M    сотрудник     0
# 5557        гражданский брак                 1      F    пенсионер     0
# 8583   Не женат / не замужем                 4      F    пенсионер     0
# 15091       гражданский брак                 1      M    сотрудник     0
# 18755        женат / замужем                 0      F    пенсионер     0
# 12736        женат / замужем                 0      F    пенсионер     0
# 15188        женат / замужем                 0      M    сотрудник     0
# 21032        женат / замужем                 0      F    пенсионер     0
# 4851        гражданский брак                 1      F    пенсионер     0
# 19688        женат / замужем                 0      F    пенсионер     0
# 10462        женат / замужем                 0      F    пенсионер     0
# 10994        женат / замужем                 0      F    пенсионер     0
# 10864        женат / замужем                 0      F    пенсионер     0
# 18428        женат / замужем                 0      F    пенсионер     0
# 13639        женат / замужем                 0      F    пенсионер     0
# 20702        женат / замужем                 0      F    пенсионер     0
# 9528          вдовец / вдова                 2      F    пенсионер     0
#
#         total_income                                purpose
# 19321  142183.724613       сделка с подержанным автомобилем
# 18328  142183.724613             покупка жилой недвижимости
# 21281  154513.982083      покупка коммерческой недвижимости
# 18349  154513.982083                покупка жилья для семьи
# 13878  154513.982083                          покупка жилья
# 16904  154513.982083     на покупку подержанного автомобиля
# 4182   154513.982083                                свадьба
# 9238   154513.982083                покупка жилья для сдачи
# 13773  154513.982083                        сыграть свадьбу
# 14432  154513.982083                  получение образования
# 12375  154513.982083                   покупка недвижимости
# 19387  154513.982083                  на проведение свадьбы
# 16902  154513.982083                        сыграть свадьбу
# 17774  154513.982083       строительство жилой недвижимости
# 10697  154513.982083                        сыграть свадьбу
# 2849   154513.982083                покупка жилья для семьи
# 20165  154513.982083                покупка жилья для семьи
# 17755  154513.982083                  заняться образованием
# 13025  154513.982083       сделка с подержанным автомобилем
# 13942  154513.982083                приобретение автомобиля
# 19184  154513.982083                        свой автомобиль
# 16378  154513.982083                     высшее образование
# 11791  154513.982083             строительство недвижимости
# 21132  154513.982083                           ремонт жилью
# 16176  154513.982083                           ремонт жилью
# 19832  154513.982083                           ремонт жилью
# 14832  133663.456146                           недвижимость
# 17379  133663.456146  операции с коммерческой недвижимостью
# 18563  133663.456146        операции со своей недвижимостью
# 21415  133663.456146                      операции с жильем
# 9627   133663.456146        операции со своей недвижимостью
# 19041  133663.456146                  на проведение свадьбы
# 18521  133663.456146                        сыграть свадьбу
# 20116  133663.456146                                свадьба
# 19946  133663.456146       сделка с подержанным автомобилем
# 7808   133663.456146                  на проведение свадьбы
# 15273  133663.456146                                свадьба
# 12373  133663.456146                   покупка недвижимости
# 5557   133663.456146                        сыграть свадьбу
# 8583   133663.456146             дополнительное образование
# 15091  133663.456146                  на проведение свадьбы
# 18755  133663.456146                  заняться образованием
# 12736  133663.456146                  заняться образованием
# 15188  133663.456146                   покупка недвижимости
# 21032  133663.456146                  заняться образованием
# 4851   133663.456146                                свадьба
# 19688  133663.456146               операции с недвижимостью
# 10462  133663.456146      покупка коммерческой недвижимости
# 10994  133663.456146                           ремонт жилью
# 10864  133663.456146                           ремонт жилью
# 18428  133663.456146                                  жилье
# 13639  133663.456146                             автомобиль
# 20702  133663.456146             дополнительное образование
# 9528   133663.456146        операции со своей недвижимостью

# %%
print ('Дубликатов в таблице:', df.duplicated().sum() )
# Out:
# Дубликатов в таблице: 54

# %% [markdown]
# Поскольку в таблице нет установочных данных, есть вероятность полного дублирования строк. В таблице выше визуально видно, что строки, отобраные как дубли, на самом деле не дубли, поэтому метод `drop duplicates` мы здесь использовать не можем.

# %% [markdown]
# Ранее визуально было замечено дублирование видов образования с учетом регистра. Проверим насколько все серьезно

# %%
df['education'].value_counts()
# Out:
# среднее                13750
# высшее                  4718
# СРЕДНЕЕ                  772
# Среднее                  711
# неоконченное высшее      668
# ВЫСШЕЕ                   274
# Высшее                   268
# начальное                250
# Неоконченное высшее       47
# НЕОКОНЧЕННОЕ ВЫСШЕЕ       29
# НАЧАЛЬНОЕ                 17
# Начальное                 15
# ученая степень             4
# УЧЕНАЯ СТЕПЕНЬ             1
# Ученая степень             1
# Name: education, dtype: int64

# %% [markdown]
# Некрасиво. Возможно разработчикам стоит перепроверить справочник для исключения подобного рода дублирования.
#
# Переведем все виды образования в нижний регистр

# %%
df['education'] = df['education'].str.lower()
df['education'].value_counts()
# Out:
# среднее                15233
# высшее                  5260
# неоконченное высшее      744
# начальное                282
# ученая степень             6
# Name: education, dtype: int64

# %% [markdown]
# Намного лучше)
#
# Проверим на дублирование столбец "Цель кредита".

# %%
df['purpose'].value_counts()
# Out:
# свадьба                                   797
# на проведение свадьбы                     777
# сыграть свадьбу                           774
# операции с недвижимостью                  676
# покупка коммерческой недвижимости         664
# операции с жильем                         653
# покупка жилья для сдачи                   653
# операции с коммерческой недвижимостью     651
# покупка жилья                             647
# жилье                                     647
# покупка жилья для семьи                   641
# строительство собственной недвижимости    635
# недвижимость                              634
# операции со своей недвижимостью           630
# строительство жилой недвижимости          626
# покупка недвижимости                      624
# покупка своего жилья                      620
# строительство недвижимости                620
# ремонт жилью                              612
# покупка жилой недвижимости                607
# на покупку своего автомобиля              505
# заняться высшим образованием              496
# автомобиль                                495
# сделка с подержанным автомобилем          489
# свой автомобиль                           480
# на покупку подержанного автомобиля        479
# автомобили                                478
# на покупку автомобиля                     472
# приобретение автомобиля                   462
# дополнительное образование                462
# сделка с автомобилем                      455
# высшее образование                        453
# образование                               447
# получение дополнительного образования     447
# получение образования                     443
# профильное образование                    436
# получение высшего образования             426
# заняться образованием                     412
# Name: purpose, dtype: int64

# %% [markdown]
# Видно, что многие цели повторяются и ввиду отсутствия или некорректности справочника записаны в разных вариациях.
#
# Лемматизируем данные для дальнейшей категоризации.

# %% [markdown]
# ### 2.4 Лемматизация <a name="p2_4"></a>

# %%
from pymystem3 import Mystem
m = Mystem()
df['lemmas'] = df['purpose'].map(m.lemmatize) #формируем столбец с леммами
df['lemmas'].head(5)
# Out:
# 0                 [покупка,  , жилье, \n]
# 1       [приобретение,  , автомобиль, \n]
# 2                 [покупка,  , жилье, \n]
# 3    [дополнительный,  , образование, \n]
# 4               [сыграть,  , свадьба, \n]
# Name: lemmas, dtype: object

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий от ревьюера</h2>
#
# Не рекомендую обращаться к колонкам датафрейма с помощью атрибутов, например, `df.purpose`. Лучше обращаться к колонкам как к ключам словаря (`df['purpose']`). Это позволит избежать возможных ошибок, если название колонки будет совпадать со встроенным атрибутом датафрейма (например, атрибут `df.size` будет выдавать информацию о датафрейме, даже если в датафрейме есть колонка с названием 'size')
#
# </div>

# %% [markdown]
# <font color=006699>Поняла, исправила)</font>
#
# Посчитаем количество лемм из возможных целей кредита и отсортируем по убыванию

# %%
from collections import Counter 
lemmas_purpose = df.lemmas.map(Counter).sum()
lemmas_purpose.most_common()
# Out:
# [(' ', 33677),
#  ('\n', 21525),
#  ('недвижимость', 6367),
#  ('покупка', 5912),
#  ('жилье', 4473),
#  ('автомобиль', 4315),
#  ('образование', 4022),
#  ('с', 2924),
#  ('операция', 2610),
#  ('свадьба', 2348),
#  ('свой', 2235),
#  ('на', 2233),
#  ('строительство', 1881),
#  ('высокий', 1375),
#  ('получение', 1316),
#  ('коммерческий', 1315),
#  ('для', 1294),
#  ('жилой', 1233),
#  ('сделка', 944),
#  ('дополнительный', 909),
#  ('заниматься', 908),
#  ('проведение', 777),
#  ('сыграть', 774),
#  ('сдача', 653),
#  ('семья', 641),
#  ('собственный', 635),
#  ('со', 630),
#  ('ремонт', 612),
#  ('подержанный', 489),
#  ('подержать', 479),
#  ('приобретение', 462),
#  ('профильный', 436)]

# %% [markdown]
# Глядя на результат, можно выделить общие цели и их унифицировать.
#
# Попробуем классифицировать цели кредита так:
# - свадьба
# - недвижимость
# - коммерческая недвижимость (выделим в отдельную категорию)
# - автомобиль
# - образование
# - ремонт
#
# Можно сгруппировать все и подругому, например, цель "покупка жилья для сдачи" выделить в отдельную категорию или добавить к коммерческой недвижимости. Но для этого нужна консультация с заказчиком исследования. Пока оставим так.

# %% [markdown]
# ### 2.5 Категоризация данных <a name="p2_5"></a>

# %% [markdown]
# Напишем функцию, присваивающую каждой строке одну из категоризированных выше целей.

# %%
def new_category(text):
    if 'свадьба' in text:
        return 'свадьба'
    elif 'коммерческий' in text:
        return 'коммерческая недвижимость'  
    elif 'автомобиль' in text:
        return 'автомобиль'
    elif 'образование' in text:
        return 'образование'
    elif 'ремонт' in text:
        return 'ремонт'
    else:
        return 'недвижимость'

# %% [markdown]
# Применим функцию к лемматизированному столбцу. Созданим новый столбец с категоризированными целями. Посчитаем количество значений по категориям.

# %%
df['purpose_cat'] = df['lemmas'].apply(new_category)
df['purpose_cat'].value_counts()
# Out:
# недвижимость                 8913
# автомобиль                   4315
# образование                  4022
# свадьба                      2348
# коммерческая недвижимость    1315
# ремонт                        612
# Name: purpose_cat, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Жирный плюс! Это один из сложнейших этапов проекта, справилась на отлично
#
# </div>

# %% [markdown]
# ### 2.5 Вывод

# %% [markdown]
# Вполне логично, что чаще всего люди берут кредиты для приобретения недвижимости.
#
# Коммерческую недвижимость выделили в отдельную категорию для эксперимента: возможно в этой категории количество просрочек будет отличаться.
#
# Таким образом, наши данные подготовлены. Переходим к ответам на поставленные в ТЗ вопросы.

# %% [markdown]
# ### Шаг 3. Ответьте на вопросы  <a name="p3"></a>

# %%
print('Средний уровень просрочки {:.2%}'.format(df['debt'].mean()))
# Out:
# Средний уровень просрочки 8.09%

# %% [markdown]
# - **Есть ли зависимость между наличием детей и возвратом кредита в срок?**

# %%
df['children'].value_counts()
# Out:
#  0     14149
#  1      4818
#  2      2055
#  3       330
#  20       76
# -1        47
#  4        41
#  5         9
# Name: children, dtype: int64

# %% [markdown]
# На стадии подготовки данных мы упустили из виду, что у нас есть отрицательные значения в столбце "количество детей".
# Так же есть сомнения, что у 76 человек по 20 детей. Отчаянные) Примем на веру.
# Нужно задать вопрос разработчикам. А пока заменим -1 на 1.

# %%
df.loc[df['children'] == -1, 'children'] = 1
df['children'].value_counts()
# Out:
# 0     14149
# 1      4865
# 2      2055
# 3       330
# 20       76
# 4        41
# 5         9
# Name: children, dtype: int64

# %% [markdown]
# Минусовые дети ушли)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# И это хорошо 😊
#
# </div>

# %% [markdown]
# Найдем зависимость наличия детей и среднего процента просрочки.

# %%
late_pay = df[df.children > 0]['debt'].mean()
print('Просрочка при наличии детей возникает у {:.2%} заемщиков'.format(late_pay))
# Out:
# Просрочка при наличии детей возникает у 9.19% заемщиков

# %%
df.groupby('children')['debt'].agg(['count','mean'])
# Out:
#           count      mean
# children
# 0         14149  0.075129
# 1          4865  0.091470
# 2          2055  0.094404
# 3           330  0.081818
# 4            41  0.097561
# 5             9  0.000000
# 20           76  0.105263

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера </h2>
#
# Здесь для вывода результатов ты используешь `groupby()` и здорово, что ты освоила данный метод. Это вполне рабочий вариант, однако в данном случае более элегантным решением будет построение [сводных таблиц](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html). Это очень важный и популярный, нужный инструмент, мне нужно убедиться, что ты умеешь им пользоваться. Реализуй то же самое используя `pivot_table()` и дай комментарии, какой из методов удобнее для тебя.
#
# </div>

# %% [markdown]
# <font color=006699>Добавила ниже.<br>Пока, с непривычки понятнее `groupby`, но с практикой и `pivot` пойму)</font>

# %%
children_pivot = df.pivot_table(index='children', values='debt', aggfunc={'count', 'mean'})
children_pivot.style.format({'mean': '{:.2%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_940dc792_0c7e_11eb_b39d_02420a397337" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>    </tr>    <tr>        <th class="index_name level0" >children</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_940dc792_0c7e_11eb_b39d_02420a397337level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_940dc792_0c7e_11eb_b39d_02420a397337row0_col0" class="data row0 col0" >14149</td>
#                         <td id="T_940dc792_0c7e_11eb_b39d_02420a397337row0_col1" class="data row0 col1" >7.51%</td>
#             </tr>
#             <tr>
#                         <th id="T_940dc792_0c7e_11eb_b39d_02420a397337level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_940dc792_0c7e_11eb_b39d_02420a397337row1_col0" class="data row1 col0" >4865</td>
#                         <td id="T_940dc792_0c7e_11eb_b39d_02420a397337row1_col1" class="data row1 col1" >9.15%</td>
#             </tr>
#             <tr>
#                         <th id="T_940dc792_0c7e_11eb_b39d_02420a397337level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_940dc792_0c7e_11eb_b39d_02420a397337row2_col0" class="data row2 col0" >2055</td>
#                         <td id="T_940dc792_0c7e_11eb_b39d_02420a397337row2_col1" class="data row2 col1" >9.44%</td>
#             </tr>
#             <tr>
#                         <th id="T_940dc792_0c7e_11eb_b39d_02420a397337level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_940dc792_0c7e_11eb_b39d_02420a397337row3_col0" class="data row3 col0" >330</td>
#                         <td id="T_940dc792_0c7e_11eb_b39d_02420a397337row3_col1" class="data row3 col1" >8.18%</td>
#             </tr>
#             <tr>
#                         <th id="T_940dc792_0c7e_11eb_b39d_02420a397337level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_940dc792_0c7e_11eb_b39d_02420a397337row4_col0" class="data row4 col0" >41</td>
#                         <td id="T_940dc792_0c7e_11eb_b39d_02420a397337row4_col1" class="data row4 col1" >9.76%</td>
#             </tr>
#             <tr>
#                         <th id="T_940dc792_0c7e_11eb_b39d_02420a397337level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_940dc792_0c7e_11eb_b39d_02420a397337row5_col0" class="data row5 col0" >9</td>
#                         <td id="T_940dc792_0c7e_11eb_b39d_02420a397337row5_col1" class="data row5 col1" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_940dc792_0c7e_11eb_b39d_02420a397337level0_row6" class="row_heading level0 row6" >20</th>
#                         <td id="T_940dc792_0c7e_11eb_b39d_02420a397337row6_col0" class="data row6 col0" >76</td>
#                         <td id="T_940dc792_0c7e_11eb_b39d_02420a397337row6_col1" class="data row6 col1" >10.53%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 </h2>
#
# У тебя отличная работа!
#
# Может тебе будет интересно: для улучшения визуализации датафрейма, можно пользоваться [style](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html) библиотеки `pandas`. Там много прикольных штук для того, чтобы сделать датафрейм красивее 😊
# Например, в нашем случае, чтобы выводить результат в процентах, а не в долях, можно прописать следующее:
#
# `children_pivot.style.format({'mean': '{:.2%}'})`
#
# </div>

# %%
plot_children = df.groupby('children')['debt'].mean().plot(kind='bar')
plot_children.set_ylabel('Просрочки по кредиту')
plot_children.set_xlabel('Количество детей')
plot_children;

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# Молодец, что визуализируешь данные, однако не забывай указывать заголовки и названия осей на графиках. Это необходимо для того, чтобы понять какие именно показатели отображены на графиках.
#
# </div>

# %% [markdown]
# <font color=006699>добавила!</font>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# Для того, чтобы не показывать вспомогательные выводы python типа `<matplotlib.axes._subplots.AxesSubplot at 0x7f5feaf7fc90>`, можно в конце строки добавить точку с запятой 😉
#
# </div>

# %% [markdown]
# <font color=006699>воу, спасибо за лайфхак)</font>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 </h2>
#
# 😎
#
# </div>

# %% [markdown]
# На графике наглядно видно зависимость между наличием детей и просрочкакми возврата кредита.
#
# - Меньше всего - 7,5% просрочек допускают лица, у которых нет детей.
# - Просрочка при наличии детей возникает у 9.21% заемщиков
# - Семьи с 20 детьми чаще всего пропускают срок выплаты - в 10 % случаев, что неудивительно).
#
# Таким образом, заемщики с детьми на 1,7% чаще допскают просрочку. Много или это мало? Вопрос.

# %% [markdown]
# - **Есть ли зависимость между семейным положением и возвратом кредита в срок?**

# %%
df.groupby('family_status')['debt'].agg(['count','mean'])
# Out:
#                        count      mean
# family_status
# Не женат / не замужем   2813  0.097405
# в разводе               1195  0.071130
# вдовец / вдова           960  0.065625
# гражданский брак        4177  0.092890
# женат / замужем        12380  0.075202

# %%
#add pivot after review
family_status = df.pivot_table(index='family_status', values='debt', aggfunc={'count', 'mean'})
family_status
# Out:
#                          count      mean
# family_status
# Не женат / не замужем   2813.0  0.097405
# в разводе               1195.0  0.071130
# вдовец / вдова           960.0  0.065625
# гражданский брак        4177.0  0.092890
# женат / замужем        12380.0  0.075202

# %%
plot_family_status = df.groupby('family_status')['debt'].mean().plot(kind='bar')
plot_family_status.set_ylabel('Просрочки по кредиту')
plot_family_status.set_xlabel('Семейное положение')
plot_family_status;

# %% [markdown]
# Исходя из графика тяжело проследить зависимость между семейным положением и наличием просрочек.
#
# Однако заметим 2 особенности:
# - вдовцы и вдовы допускают просрочки чуть реже
# - пары, живущие в официальном браке, почти на 2% реже допускают просрочки, чем пары, живущие в гражданском браке. Общий бюджет - общая ответственность)

# %% [markdown]
# - **Есть ли зависимость между уровнем дохода и возвратом кредита в срок?**
#
# Для удобства разделим доход по выборке на 5 равных групп используя 'qcut' и посчитаем процент задолженности.

# %%
df['income_group'] = pd.qcut(df['total_income'],5)
df.groupby('income_group')['debt'].agg(['count','mean'])
# Out:
#                            count      mean
# income_group
# (20667.263, 98662.456]      4305  0.080139
# (98662.456, 133663.456]     4836  0.079198
# (133663.456, 156178.396]    3774  0.089560
# (156178.396, 214254.147]    4305  0.086411
# (214254.147, 2265604.029]   4305  0.070383

# %%
#add pivot after review
income_group = df.pivot_table(index='income_group', values='debt', aggfunc={'count', 'mean'})
income_group
# Out:
#                             count      mean
# income_group
# (20667.263, 98662.456]     4305.0  0.080139
# (98662.456, 133663.456]    4836.0  0.079198
# (133663.456, 156178.396]   3774.0  0.089560
# (156178.396, 214254.147]   4305.0  0.086411
# (214254.147, 2265604.029]  4305.0  0.070383

# %%
plot_income = df.groupby('income_group')['debt'].mean().plot(kind='bar', color='#a98d19')
plot_income.set_ylabel('Просрочки по кредиту')
plot_income.set_xlabel('Семейное положение')
plot_income;

# %% [markdown]
# Закономерность между уровнем дохода и возвратом кредита вполне логична: люди с наибольшим доходом (более 214 тыс.) совершают просрочки реже - менее, чем в 7% случаев.
#
# Можно было выбрать и более четкие параметры категорий по доходу для большей наглядности, но оставим так, чтобы выборки были более равные.

# %% [markdown]
# - **Как разные цели кредита влияют на его возврат в срок?**

# %%
df.groupby('purpose_cat')['debt'].agg(['count','mean']).sort_values(by='mean',ascending=True)
# Out:
#                            count      mean
# purpose_cat
# ремонт                       612  0.057190
# недвижимость                8913  0.072703
# коммерческая недвижимость   1315  0.075285
# свадьба                     2348  0.079216
# образование                 4022  0.091994
# автомобиль                  4315  0.093395

# %% [markdown]
# Неожиданно, самым вовремя "возвращаемым" кредитом оказался кредит на ремонт. Выдача же денежных средств на покупку автомобиля и образование являются наиболее рисковыми историями.
#
# Выделяя в отдельную категорию коммерческую недвижимость, мы рассчитывали увидеть отличия в % возврата от покупки жилья, но предположение не подтвердилось. В обоих случаях процент просрочек примерно одинаков и равен 7,2-7,5%

# %% [markdown]
# ### Шаг 4. Общий вывод <a name="p4"></a>

# %% [markdown]
# В ходе исследования была проанализирована статистика платёжеспособности клиентов.
# <font color=006699>
#
# Были обработаны пропуски методом замены пустого дохода на медианное значение по возрасту заемщика, разбитого на 3 категории.
# Пропуски могли появиться ввиду прогрмамной ошибки при заполнении данных, рекомендую обратиться к разработчикам с целью недопущения их возникновения.
#
# Произведена замена дробного типа на целочисленный, удалены дубликаты в категории образование. Рекомендую программистам переработать справочник.
#
# </font>
# Обработанные данные были лемматизированы с целью выделения категорий.
#
# Были выявлены закономерности между наличием детей/целью кредита/уровнем дохода и вероятностью просрочек
#
# Результаты исследования могут быть учтены при построении модели специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.
#
# <font color=006699>
# <h4>Рекомендации</h4>
#     - обратиться к программистам и уточнить причину возникновения пропусков в слобцах `total_income` и `days_employed`;
#     - обратиться к программистам и уточнить причину возникновения отрицательных значений в столбцах `children`,`days_employed`;
#     - разработать функцию для оценки рисков невозврата крелита на основании найденных закономерностей.
# </font>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Другое дело! Пример полного и развернутого вывода 👏
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера </h2>
#
# В общий вывод стоит добавить результаты работ на втором и третьем шагах, как были обрабатаны пропуски, их возможные причины и тд. Это позволит людям, у которых нет времени вникать в работу, понять что было сделано и как. Также полезно выделить блок «Рекомендации».
#
# </div>

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px">
#
# У тебя получилась очень хорошая работа! Многие моменты сделаны просто прекрасно. Ты показываешь отличное владение изучаемым материалом: уверенно пользуешься pandas, умеешь подготавливать, очищать, обогощать данные. На протяжении всей работы чувствуется глубина проработки задачи и это безусловный плюс для нас.
#
# Остались небольшие доработки:
#
# - В шаге 3 необходимо получить результаты с использованием метода `pivot_table()`;
# - В шаге 4 необходимо дополнить общий вывод.
#
# Жду твоих исправлений, у тебя все получится 😊
#
# </div>

# %% [markdown]
# ### Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл;
# - [x]  файл изучен;
# - [x]  определены пропущенные значения;
# - [x]  заполнены пропущенные значения;
# - [x]  есть пояснение, какие пропущенные значения обнаружены;
# - [x]  описаны возможные причины появления пропусков в данных;
# - [x]  объяснено, по какому принципу заполнены пропуски;
# - [x]  заменен вещественный тип данных на целочисленный;
# - [x]  есть пояснение, какой метод используется для изменения типа данных и почему;
# - [x]  удалены дубликаты;
# - [x]  есть пояснение, какой метод используется для поиска и удаления дубликатов;
# - [x]  описаны возможные причины появления дубликатов в данных;
# - [x]  выделены леммы в значениях столбца с целями получения кредита;
# - [x]  описан процесс лемматизации;
# - [x]  данные категоризированы;
# - [x]  есть объяснение принципа категоризации данных;
# - [x]  есть ответ на вопрос: "Есть ли зависимость между наличием детей и возвратом кредита в срок?";
# - [x]  есть ответ на вопрос: "Есть ли зависимость между семейным положением и возвратом кредита в срок?";
# - [x]  есть ответ на вопрос: "Есть ли зависимость между уровнем дохода и возвратом кредита в срок?";
# - [x]  есть ответ на вопрос: "Как разные цели кредита влияют на его возврат в срок?";
# - [x]  в каждом этапе есть выводы;
# - [x]  есть общий вывод.

# %% [markdown]
# ### *Спасибо за любые комментарии!*
